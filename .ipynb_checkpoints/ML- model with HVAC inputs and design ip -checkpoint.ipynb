# %%
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm

from keras.models import Sequential
from keras.layers import Dense
from keras import optimizers
from keras.regularizers import l2

from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\u0107464\AppData\Local\Continuum\anaconda3\envs\ML_research\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# C:\Users\u0107464\AppData\Local\Continuum\anaconda3\envs\ML_research\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Load data

# %%
data_path = 'C:/Users/u0107464/OneDrive/PythonScript/Arch_model_design_space_exp/Model_extracted_data/Data/Correlation_analysis/'

data = pd.read_csv(data_path+'Correlation_analysis_chiller_data.csv')
data.head()
# Out:
#      $X    $Y     $H     $SL1     $SL2     $SL3     $SL4  $WWR_S  $WWR_N  \
# 0  20.0  20.0  3.000  0.01000  0.01000  0.01000  0.01000  0.0100  0.0100
# 1  50.0  50.0  4.500  2.50500  2.50500  2.50500  2.50500  0.4800  0.4800
# 2  65.0  35.0  3.750  1.25750  3.75250  3.75250  1.25750  0.7150  0.7150
# 3  35.0  65.0  5.250  3.75250  1.25750  1.25750  3.75250  0.2450  0.2450
# 4  42.5  42.5  4.875  4.37625  1.88125  0.63375  1.88125  0.8325  0.8325
#
#    $WWR_E          ...            $ChillerTypeCat  Peak: Ground Floor  \
# 0  0.0100          ...                          0         11337.83316
# 1  0.4800          ...                          0        153385.91250
# 2  0.7150          ...                          1        101713.18150
# 3  0.2450          ...                          0        117188.67960
# 4  0.5975          ...                          1        202009.34090
#
#    Peak: Intermediate Floor  Peak: Top Floor  Mean: Ground Floor  \
# 0               11414.46115      10412.70053         2113.167496
# 1              156708.68690     131153.98670        21212.919620
# 2              105411.62670      95695.13032        15004.982930
# 3              124974.75170     113182.75430        19501.604010
# 4              209944.82950     170183.17070        21693.299280
#
#    Mean: Intermediate Floor  Mean: Top Floor  Peak: Chiller Energy  \
# 0                2487.05647      2407.259478            24023.1954
# 1               23818.69559     21388.286380           180486.0413
# 2               17410.29156     15835.306020           107845.8289
# 3               22144.84171     20849.448860           182746.3519
# 4               23712.53308     21126.595210           275340.6081
#
#    Mean: Chiller Energy  Total: Chiller Energy
# 0           9511.314472           8.331911e+07
# 1          55010.154130           4.818890e+08
# 2          41685.852000           3.651681e+08
# 3          61094.038630           5.351838e+08
# 4          90263.074890           7.907045e+08
#
# [5 rows x 35 columns]

# %%
data.describe()
# Out:
#                 $X           $Y           $H         $SL1         $SL2  \
# count  4500.000000  4500.000000  4500.000000  4500.000000  4500.000000
# mean     50.017578    50.002578     4.498527     2.502031     2.501615
# std      17.322179    17.323634     0.866154     1.440758     1.440689
# min      20.000000    20.000000     3.000000     0.010000     0.010000
# 25%      34.992676    34.992676     3.749268     1.256282     1.256282
# 50%      49.985352    49.985352     4.498535     2.502563     2.502563
# 75%      64.978027    64.978027     5.247803     3.748845     3.748845
# max      79.970703    79.970703     5.997070     4.995127     4.995127
#
#               $SL3         $SL4       $WWR_S       $WWR_N       $WWR_E  \
# count  4500.000000  4500.000000  4500.000000  4500.000000  4500.000000
# mean      2.504500     2.505292     0.480275     0.479707     0.480241
# std       1.440707     1.440686     0.271381     0.271375     0.271394
# min       0.010000     0.010000     0.010000     0.010000     0.010000
# 25%       1.256282     1.256891     0.244885     0.244885     0.244885
# 50%       2.502563     2.503782     0.479771     0.479771     0.479771
# 75%       3.748845     3.750673     0.714656     0.714656     0.714656
# max       4.995127     4.997563     0.949541     0.949541     0.949541
#
#                ...            $ChillerTypeCat  Peak: Ground Floor  \
# count          ...                4500.000000         4500.000000
# mean           ...                   0.499333       137889.767218
# std            ...                   0.500055        70088.535009
# min            ...                   0.000000        11323.335280
# 25%            ...                   0.000000        84457.472250
# 50%            ...                   0.000000       125632.954750
# 75%            ...                   1.000000       179025.424300
# max            ...                   1.000000       499700.688800
#
#        Peak: Intermediate Floor  Peak: Top Floor  Mean: Ground Floor  \
# count              4.500000e+03      4500.000000         4500.000000
# mean               4.348202e+05    125083.567595        20712.528801
# std                3.451883e+05     61093.359096        10860.635127
# min                1.141446e+04     10399.375350         2113.167496
# 25%                1.655355e+05     78011.481200        12462.219070
# 50%                3.424381e+05    114395.971450        18762.916390
# 75%                6.141979e+05    161306.232100        26941.787840
# max                2.497191e+06    408189.815400        70820.685020
#
#        Mean: Intermediate Floor  Mean: Top Floor  Peak: Chiller Energy  \
# count               4500.000000      4500.000000          4.500000e+03
# mean               75599.127636     21589.030238          2.911769e+05
# std                62269.478774     11225.173658          1.925209e+05
# min                 2487.056470      2407.259478          2.402320e+04
# 25%                27482.536790     13077.789000          1.514525e+05
# 50%                58205.032445     19384.319960          2.411453e+05
# 75%               108004.963200     27957.939685          3.815975e+05
# max               415246.675100     69058.712140          1.557656e+06
#
#        Mean: Chiller Energy  Total: Chiller Energy
# count           4500.000000           4.500000e+03
# mean          101808.056058           8.918386e+08
# std            66490.230952           5.824544e+08
# min             9434.070998           8.264246e+07
# 25%            53591.794567           4.694641e+08
# 50%            85162.206215           7.460209e+08
# 75%           133061.798275           1.165621e+09
# max           524017.105100           4.590390e+09
#
# [8 rows x 35 columns]

# %%
data['Number_of_zones'] = 0

data['Number_of_zones'][0:1500] =3  
data['Number_of_zones'][1500*1:1500*2] = 5  
data['Number_of_zones'][1500*2:1500*3] = 7  
data['Number_of_zones'].plot()
# Out:
# C:\Users\u0107464\AppData\Local\Continuum\anaconda3\envs\ML_research\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\u0107464\AppData\Local\Continuum\anaconda3\envs\ML_research\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\u0107464\AppData\Local\Continuum\anaconda3\envs\ML_research\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
data.columns
# Out:
# Index(['$X', '$Y', '$H', '$SL1', '$SL2', '$SL3', '$SL4', '$WWR_S', '$WWR_N',
#        '$WWR_E', ' $WWR_W', '$ORI', '$WALL_U', '$WIN_U', '$GFLOOR_U',
#        ' $FLOOR_SH', '$ROOF_U', '$WIN_G', '$ACH', '$LHG', '$EHG',
#        '$ChillerCOP', '$BoilerEfficiency', '$ChillerPumpTypeCat',
#        '$BoilerPumpTypeCat', '$ChillerTypeCat', 'Peak: Ground Floor',
#        'Peak: Intermediate Floor', 'Peak: Top Floor', 'Mean: Ground Floor',
#        'Mean: Intermediate Floor', 'Mean: Top Floor', 'Peak: Chiller Energy',
#        'Mean: Chiller Energy', 'Total: Chiller Energy', 'Number_of_zones'],
#       dtype='object')

# %% [markdown]
# # Linear regression

# %% [markdown]
# # Design Input features

# %%
x_list = ['$X', '$Y', '$H', '$SL1', '$SL2', '$SL3', '$SL4', '$WWR_S', '$WWR_N',
       '$WWR_E', ' $WWR_W', '$ORI', '$WALL_U', '$WIN_U', '$GFLOOR_U',
       ' $FLOOR_SH', '$ROOF_U', '$WIN_G', '$ACH', '$LHG', '$EHG',
       '$ChillerCOP', '$ChillerPumpTypeCat','$ChillerTypeCat','Number_of_zones']

x = data.filter(items=x_list).values
scalar_x = MinMaxScaler()
x = scalar_x.fit_transform(x)

y = data['Total: Chiller Energy'].values.reshape(len(x),1)
scalar_y = MinMaxScaler()
y = scalar_y.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
linear_model = sm.OLS(y_train, x_train).fit()
print(linear_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     2394.
# Date:                Tue, 12 Jun 2018   Prob (F-statistic):               0.00
# Time:                        12:40:37   Log-Likelihood:                 5508.6
# No. Observations:                3600   AIC:                        -1.097e+04
# Df Residuals:                    3575   BIC:                        -1.081e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1971      0.003     66.181      0.000       0.191       0.203
# x2             0.1999      0.003     67.095      0.000       0.194       0.206
# x3             0.0356      0.003     12.070      0.000       0.030       0.041
# x4            -0.0136      0.003     -4.569      0.000      -0.019      -0.008
# x5            -0.0139      0.003     -4.670      0.000      -0.020      -0.008
# x6            -0.0139      0.003     -4.699      0.000      -0.020      -0.008
# x7            -0.0139      0.003     -4.661      0.000      -0.020      -0.008
# x8             0.0012      0.003      0.390      0.697      -0.005       0.007
# x9            -0.0012      0.003     -0.392      0.695      -0.007       0.005
# x10            0.0035      0.003      1.190      0.234      -0.002       0.009
# x11            0.0017      0.003      0.562      0.574      -0.004       0.007
# x12           -0.0178      0.003     -5.964      0.000      -0.024      -0.012
# x13           -0.0164      0.003     -5.512      0.000      -0.022      -0.011
# x14           -0.0119      0.003     -4.015      0.000      -0.018      -0.006
# x15           -0.0140      0.003     -4.702      0.000      -0.020      -0.008
# x16           -0.0148      0.003     -4.991      0.000      -0.021      -0.009
# x17           -0.0126      0.003     -4.206      0.000      -0.018      -0.007
# x18            0.0443      0.003     14.939      0.000       0.038       0.050
# x19            0.0117      0.003      3.923      0.000       0.006       0.017
# x20            0.0009      0.003      0.290      0.772      -0.005       0.007
# x21           -0.0028      0.003     -0.938      0.348      -0.009       0.003
# x22           -0.1499      0.003    -50.520      0.000      -0.156      -0.144
# x23           -0.0054      0.002     -3.114      0.002      -0.009      -0.002
# x24            0.0131      0.002      7.530      0.000       0.010       0.017
# x25            0.1561      0.002     73.413      0.000       0.152       0.160
# ==============================================================================
# Omnibus:                     1623.926   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13837.864
# Skew:                           1.943   Prob(JB):                         0.00
# Kurtosis:                      11.783   Cond. No.                         9.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_test_pred = linear_model.predict(x_test)

# %%
plt.scatter(y_test,y_test_pred)
plt.plot(y_test,y_test,'black')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

print("R^2 ",metrics.r2_score(y_test,y_test_pred))
# Out:
# R^2  0.8207203027660616

# %% [markdown]
# # HVAC Input features

# %%
x_list = ['$ChillerCOP', '$ChillerPumpTypeCat','$ChillerTypeCat','Number_of_zones','Peak: Ground Floor',
       'Peak: Intermediate Floor', 'Peak: Top Floor', 'Mean: Ground Floor','Mean: Intermediate Floor', 'Mean: Top Floor']

x = data.filter(items=x_list).values
scalar_x = MinMaxScaler()
x = scalar_x.fit_transform(x)

y = data['Total: Chiller Energy'].values.reshape(len(x),1)
scalar_y = MinMaxScaler()
y = scalar_y.fit_transform(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
linear_model = sm.OLS(y_train, x_train).fit()
print(linear_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.973
# Method:                 Least Squares   F-statistic:                 1.314e+04
# Date:                Fri, 08 Jun 2018   Prob (F-statistic):               0.00
# Time:                        14:12:18   Log-Likelihood:                 6861.3
# No. Observations:                3600   AIC:                        -1.370e+04
# Df Residuals:                    3590   BIC:                        -1.364e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1201      0.002    -63.993      0.000      -0.124      -0.116
# x2             0.0059      0.001      5.108      0.000       0.004       0.008
# x3             0.0238      0.001     20.540      0.000       0.022       0.026
# x4             0.0588      0.003     23.054      0.000       0.054       0.064
# x5            -0.6064      0.032    -19.245      0.000      -0.668      -0.545
# x6             0.0412      0.028      1.454      0.146      -0.014       0.097
# x7             1.2172      0.033     37.038      0.000       1.153       1.282
# x8            -0.0219      0.038     -0.581      0.561      -0.096       0.052
# x9             0.4019      0.026     15.255      0.000       0.350       0.454
# x10           -0.2572      0.036     -7.162      0.000      -0.328      -0.187
# ==============================================================================
# Omnibus:                      860.772   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5578.474
# Skew:                           0.976   Prob(JB):                         0.00
# Kurtosis:                       8.777   Cond. No.                         122.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
y_test_pred = linear_model.predict(x_test)

# %%
plt.scatter(y_test,y_test_pred)
plt.plot(y_test,y_test,'black')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

print("R^2 ",metrics.r2_score(y_test,y_test_pred))
# Out:
# R^2  0.932142876103295

# %% [markdown]
# # Neural network

# %% [markdown]
# # Design inputs

# %%
x_list = ['$X', '$Y', '$H', '$SL1', '$SL2', '$SL3', '$SL4', '$WWR_S', '$WWR_N',
       '$WWR_E', ' $WWR_W', '$ORI', '$WALL_U', '$WIN_U', '$GFLOOR_U',
       ' $FLOOR_SH', '$ROOF_U', '$WIN_G', '$ACH', '$LHG', '$EHG',
       '$ChillerCOP', '$ChillerPumpTypeCat','$ChillerTypeCat','Number_of_zones']

x = data.filter(items=x_list).values
scalar_x = MinMaxScaler()
x = scalar_x.fit_transform(x)

y = data['Total: Chiller Energy'].values.reshape(len(x),1)
scalar_y = MinMaxScaler()
y = scalar_y.fit_transform(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(60, input_dim=len(x_list), activation='relu'))
model.add(Dense(1, activation='relu'))

Adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='mse', optimizer=Adam)

# %%
history = model.fit(x_train, y_train,validation_data=(x_test,y_test), epochs=300, batch_size=50, verbose=2)
# Out:
# Train on 3600 samples, validate on 900 samples
# Epoch 1/300
#  - 1s - loss: 0.0326 - val_loss: 0.0083
# Epoch 2/300
#  - 0s - loss: 0.0049 - val_loss: 0.0043
# Epoch 3/300
#  - 0s - loss: 0.0034 - val_loss: 0.0041
# Epoch 4/300
#  - 0s - loss: 0.0028 - val_loss: 0.0030
# Epoch 5/300
#  - 0s - loss: 0.0026 - val_loss: 0.0027
# Epoch 6/300
#  - 0s - loss: 0.0023 - val_loss: 0.0030
# Epoch 7/300
#  - 0s - loss: 0.0022 - val_loss: 0.0022
# Epoch 8/300
#  - 0s - loss: 0.0019 - val_loss: 0.0021
# Epoch 9/300
#  - 0s - loss: 0.0018 - val_loss: 0.0020
# Epoch 10/300
#  - 0s - loss: 0.0019 - val_loss: 0.0020
# Epoch 11/300
#  - 0s - loss: 0.0019 - val_loss: 0.0020
# Epoch 12/300
#  - 0s - loss: 0.0017 - val_loss: 0.0020
# Epoch 13/300
#  - 0s - loss: 0.0016 - val_loss: 0.0020
# Epoch 14/300
#  - 0s - loss: 0.0015 - val_loss: 0.0017
# Epoch 15/300
#  - 0s - loss: 0.0014 - val_loss: 0.0017
# Epoch 16/300
#  - 0s - loss: 0.0014 - val_loss: 0.0016
# Epoch 17/300
#  - 0s - loss: 0.0014 - val_loss: 0.0015
# Epoch 18/300
#  - 0s - loss: 0.0014 - val_loss: 0.0016
# Epoch 19/300
#  - 0s - loss: 0.0013 - val_loss: 0.0014
# Epoch 20/300
#  - 0s - loss: 0.0012 - val_loss: 0.0015
# Epoch 21/300
#  - 0s - loss: 0.0012 - val_loss: 0.0015
# Epoch 22/300
#  - 0s - loss: 0.0011 - val_loss: 0.0015
# Epoch 23/300
#  - 0s - loss: 0.0011 - val_loss: 0.0014
# Epoch 24/300
#  - 0s - loss: 0.0011 - val_loss: 0.0013
# Epoch 25/300
#  - 0s - loss: 0.0010 - val_loss: 0.0013
# Epoch 26/300
#  - 0s - loss: 9.6324e-04 - val_loss: 0.0012
# Epoch 27/300
#  - 0s - loss: 9.3931e-04 - val_loss: 0.0012
# Epoch 28/300
#  - 0s - loss: 9.1368e-04 - val_loss: 0.0012
# Epoch 29/300
#  - 0s - loss: 8.9579e-04 - val_loss: 0.0011
# Epoch 30/300
#  - 0s - loss: 0.0010 - val_loss: 0.0011
# Epoch 31/300
#  - 0s - loss: 8.6944e-04 - val_loss: 0.0012
# Epoch 32/300
#  - 0s - loss: 7.9306e-04 - val_loss: 0.0011
# Epoch 33/300
#  - 0s - loss: 8.1326e-04 - val_loss: 0.0011
# Epoch 34/300
#  - 0s - loss: 7.8607e-04 - val_loss: 0.0010
# Epoch 35/300
#  - 0s - loss: 8.2147e-04 - val_loss: 0.0011
# Epoch 36/300
#  - 0s - loss: 7.9072e-04 - val_loss: 0.0012
# Epoch 37/300
#  - 0s - loss: 7.3387e-04 - val_loss: 9.9882e-04
# Epoch 38/300
#  - 0s - loss: 7.4876e-04 - val_loss: 9.5196e-04
# Epoch 39/300
#  - 0s - loss: 7.1910e-04 - val_loss: 9.4824e-04
# Epoch 40/300
#  - 0s - loss: 7.2497e-04 - val_loss: 9.7255e-04
# Epoch 41/300
#  - 0s - loss: 6.6184e-04 - val_loss: 9.1562e-04
# Epoch 42/300
#  - 0s - loss: 6.4864e-04 - val_loss: 9.0111e-04
# Epoch 43/300
#  - 0s - loss: 6.2529e-04 - val_loss: 9.0574e-04
# Epoch 44/300
#  - 0s - loss: 6.6320e-04 - val_loss: 9.1455e-04
# Epoch 45/300
#  - 0s - loss: 6.7074e-04 - val_loss: 8.3672e-04
# Epoch 46/300
#  - 0s - loss: 5.9216e-04 - val_loss: 9.0893e-04
# Epoch 47/300
#  - 0s - loss: 6.3862e-04 - val_loss: 8.2300e-04
# Epoch 48/300
#  - 0s - loss: 5.8470e-04 - val_loss: 8.6642e-04
# Epoch 49/300
#  - 0s - loss: 6.2816e-04 - val_loss: 8.4609e-04
# Epoch 50/300
#  - 0s - loss: 5.6625e-04 - val_loss: 8.5193e-04
# Epoch 51/300
#  - 0s - loss: 5.9208e-04 - val_loss: 7.9556e-04
# Epoch 52/300
#  - 0s - loss: 5.3679e-04 - val_loss: 7.7731e-04
# Epoch 53/300
#  - 0s - loss: 5.3514e-04 - val_loss: 8.4955e-04
# Epoch 54/300
#  - 0s - loss: 5.3156e-04 - val_loss: 7.5349e-04
# Epoch 55/300
#  - 0s - loss: 5.5452e-04 - val_loss: 7.8150e-04
# Epoch 56/300
#  - 0s - loss: 6.1943e-04 - val_loss: 0.0011
# Epoch 57/300
#  - 0s - loss: 5.6905e-04 - val_loss: 7.4062e-04
# Epoch 58/300
#  - 0s - loss: 5.0847e-04 - val_loss: 7.4660e-04
# Epoch 59/300
#  - 0s - loss: 4.9918e-04 - val_loss: 7.4134e-04
# Epoch 60/300
#  - 0s - loss: 5.1546e-04 - val_loss: 7.5046e-04
# Epoch 61/300
#  - 0s - loss: 5.1328e-04 - val_loss: 7.5386e-04
# Epoch 62/300
#  - 0s - loss: 4.6953e-04 - val_loss: 6.9346e-04
# Epoch 63/300
#  - 0s - loss: 4.8034e-04 - val_loss: 8.0382e-04
# Epoch 64/300
#  - 0s - loss: 4.7701e-04 - val_loss: 6.9572e-04
# Epoch 65/300
#  - 0s - loss: 4.6363e-04 - val_loss: 7.2914e-04
# Epoch 66/300
#  - 0s - loss: 4.5655e-04 - val_loss: 7.1006e-04
# Epoch 67/300
#  - 0s - loss: 4.6579e-04 - val_loss: 6.8262e-04
# Epoch 68/300
#  - 0s - loss: 4.5387e-04 - val_loss: 8.3229e-04
# Epoch 69/300
#  - 0s - loss: 4.8000e-04 - val_loss: 6.5317e-04
# Epoch 70/300
#  - 0s - loss: 4.4265e-04 - val_loss: 6.6018e-04
# Epoch 71/300
#  - 0s - loss: 4.6413e-04 - val_loss: 6.4325e-04
# Epoch 72/300
#  - 0s - loss: 4.5719e-04 - val_loss: 7.3559e-04
# Epoch 73/300
#  - 0s - loss: 4.3290e-04 - val_loss: 6.1942e-04
# Epoch 74/300
#  - 0s - loss: 4.7443e-04 - val_loss: 6.1463e-04
# Epoch 75/300
#  - 0s - loss: 4.0669e-04 - val_loss: 6.5208e-04
# Epoch 76/300
#  - 0s - loss: 4.5048e-04 - val_loss: 7.1471e-04
# Epoch 77/300
#  - 0s - loss: 4.0466e-04 - val_loss: 6.2896e-04
# Epoch 78/300
#  - 0s - loss: 4.2440e-04 - val_loss: 5.9185e-04
# Epoch 79/300
#  - 0s - loss: 4.1601e-04 - val_loss: 6.4995e-04
# Epoch 80/300
#  - 0s - loss: 4.5571e-04 - val_loss: 6.1675e-04
# Epoch 81/300
#  - 0s - loss: 4.4458e-04 - val_loss: 5.9289e-04
# Epoch 82/300
#  - 0s - loss: 3.9317e-04 - val_loss: 5.9024e-04
# Epoch 83/300
#  - 0s - loss: 3.7465e-04 - val_loss: 5.7419e-04
# Epoch 84/300
#  - 0s - loss: 3.7500e-04 - val_loss: 6.6678e-04
# Epoch 85/300
#  - 0s - loss: 3.8555e-04 - val_loss: 5.8434e-04
# Epoch 86/300
#  - 0s - loss: 3.8187e-04 - val_loss: 5.9110e-04
# Epoch 87/300
#  - 0s - loss: 3.6250e-04 - val_loss: 5.6496e-04
# Epoch 88/300
#  - 0s - loss: 3.6707e-04 - val_loss: 5.5204e-04
# Epoch 89/300
#  - 0s - loss: 3.6857e-04 - val_loss: 5.6727e-04
# Epoch 90/300
#  - 0s - loss: 3.7223e-04 - val_loss: 7.7924e-04
# Epoch 91/300
#  - 0s - loss: 3.5873e-04 - val_loss: 6.9158e-04
# Epoch 92/300
#  - 0s - loss: 3.6991e-04 - val_loss: 6.4276e-04
# Epoch 93/300
#  - 0s - loss: 3.5599e-04 - val_loss: 6.0714e-04
# Epoch 94/300
#  - 0s - loss: 3.4650e-04 - val_loss: 5.8197e-04
# Epoch 95/300
#  - 0s - loss: 3.7029e-04 - val_loss: 6.0377e-04
# Epoch 96/300
#  - 0s - loss: 3.9881e-04 - val_loss: 6.1618e-04
# Epoch 97/300
#  - 0s - loss: 3.4026e-04 - val_loss: 5.2099e-04
# Epoch 98/300
#  - 0s - loss: 3.5335e-04 - val_loss: 5.4082e-04
# Epoch 99/300
#  - 0s - loss: 3.4263e-04 - val_loss: 6.6057e-04
# Epoch 100/300
#  - 0s - loss: 3.2838e-04 - val_loss: 5.3060e-04
# Epoch 101/300
#  - 0s - loss: 3.4686e-04 - val_loss: 5.2360e-04
# Epoch 102/300
#  - 0s - loss: 3.7127e-04 - val_loss: 5.6121e-04
# Epoch 103/300
#  - 0s - loss: 3.3782e-04 - val_loss: 5.0489e-04
# Epoch 104/300
#  - 0s - loss: 3.1257e-04 - val_loss: 5.0054e-04
# Epoch 105/300
#  - 0s - loss: 3.7437e-04 - val_loss: 5.0020e-04
# Epoch 106/300
#  - 0s - loss: 3.2655e-04 - val_loss: 4.9611e-04
# Epoch 107/300
#  - 0s - loss: 3.1437e-04 - val_loss: 5.0580e-04
# Epoch 108/300
#  - 0s - loss: 3.2302e-04 - val_loss: 4.9790e-04
# Epoch 109/300
#  - 0s - loss: 3.4143e-04 - val_loss: 5.2066e-04
# Epoch 110/300
#  - 0s - loss: 3.4842e-04 - val_loss: 5.1766e-04
# Epoch 111/300
#  - 0s - loss: 3.0404e-04 - val_loss: 4.8001e-04
# Epoch 112/300
#  - 0s - loss: 3.0871e-04 - val_loss: 5.0832e-04
# Epoch 113/300
#  - 0s - loss: 3.1053e-04 - val_loss: 5.1644e-04
# Epoch 114/300
#  - 0s - loss: 3.0672e-04 - val_loss: 4.7731e-04
# Epoch 115/300
#  - 0s - loss: 2.9373e-04 - val_loss: 5.0112e-04
# Epoch 116/300
#  - 0s - loss: 3.3379e-04 - val_loss: 5.2549e-04
# Epoch 117/300
#  - 0s - loss: 2.9494e-04 - val_loss: 4.5668e-04
# Epoch 118/300
#  - 0s - loss: 2.9172e-04 - val_loss: 5.0376e-04
# Epoch 119/300
#  - 0s - loss: 3.1349e-04 - val_loss: 4.5586e-04
# Epoch 120/300
#  - 0s - loss: 2.9371e-04 - val_loss: 4.6126e-04
# Epoch 121/300
#  - 0s - loss: 3.2373e-04 - val_loss: 5.0205e-04
# Epoch 122/300
#  - 0s - loss: 2.9892e-04 - val_loss: 5.4229e-04
# Epoch 123/300
#  - 0s - loss: 3.4729e-04 - val_loss: 5.3432e-04
# Epoch 124/300
#  - 0s - loss: 2.9467e-04 - val_loss: 4.7396e-04
# Epoch 125/300
#  - 0s - loss: 2.9548e-04 - val_loss: 4.5690e-04
# Epoch 126/300
#  - 0s - loss: 2.7496e-04 - val_loss: 4.5238e-04
# Epoch 127/300
#  - 0s - loss: 2.9090e-04 - val_loss: 4.6856e-04
# Epoch 128/300
#  - 0s - loss: 2.8695e-04 - val_loss: 4.9711e-04
# Epoch 129/300
#  - 0s - loss: 2.9270e-04 - val_loss: 4.5595e-04
# Epoch 130/300
#  - 0s - loss: 2.7928e-04 - val_loss: 5.2257e-04
# Epoch 131/300
#  - 0s - loss: 2.7578e-04 - val_loss: 4.6109e-04
# Epoch 132/300
#  - 0s - loss: 2.8458e-04 - val_loss: 4.8274e-04
# Epoch 133/300
#  - 0s - loss: 2.8360e-04 - val_loss: 4.5211e-04
# Epoch 134/300
#  - 0s - loss: 2.9199e-04 - val_loss: 4.6805e-04
# Epoch 135/300
#  - 0s - loss: 2.6200e-04 - val_loss: 4.3730e-04
# Epoch 136/300
#  - 0s - loss: 2.6064e-04 - val_loss: 5.3120e-04
# Epoch 137/300
#  - 0s - loss: 2.8235e-04 - val_loss: 5.0775e-04
# Epoch 138/300
#  - 0s - loss: 2.7698e-04 - val_loss: 4.8620e-04
# Epoch 139/300
#  - 0s - loss: 2.7087e-04 - val_loss: 4.4900e-04
# Epoch 140/300
#  - 0s - loss: 2.9170e-04 - val_loss: 5.1031e-04
# Epoch 141/300
#  - 0s - loss: 3.1093e-04 - val_loss: 5.6533e-04
# Epoch 142/300
#  - 0s - loss: 2.8287e-04 - val_loss: 4.3879e-04
# Epoch 143/300
#  - 0s - loss: 2.6102e-04 - val_loss: 4.2677e-04
# Epoch 144/300
#  - 0s - loss: 2.7337e-04 - val_loss: 4.2305e-04
# Epoch 145/300
#  - 0s - loss: 2.5338e-04 - val_loss: 4.4006e-04
# Epoch 146/300
#  - 0s - loss: 2.6864e-04 - val_loss: 4.1997e-04
# Epoch 147/300
#  - 0s - loss: 2.6845e-04 - val_loss: 6.4312e-04
# Epoch 148/300
#  - 0s - loss: 2.9502e-04 - val_loss: 4.3669e-04
# Epoch 149/300
#  - 0s - loss: 2.5424e-04 - val_loss: 4.3420e-04
# Epoch 150/300
#  - 0s - loss: 2.5782e-04 - val_loss: 4.2315e-04
# Epoch 151/300
#  - 0s - loss: 2.7583e-04 - val_loss: 4.5023e-04
# Epoch 152/300
#  - 0s - loss: 2.6396e-04 - val_loss: 4.3318e-04
# Epoch 153/300
#  - 0s - loss: 2.8954e-04 - val_loss: 4.0802e-04
# Epoch 154/300
#  - 0s - loss: 2.6689e-04 - val_loss: 4.2835e-04
# Epoch 155/300
#  - 0s - loss: 2.4986e-04 - val_loss: 4.0048e-04
# Epoch 156/300
#  - 0s - loss: 2.8749e-04 - val_loss: 4.4564e-04
# Epoch 157/300
#  - 0s - loss: 2.5436e-04 - val_loss: 4.2240e-04
# Epoch 158/300
#  - 0s - loss: 2.6053e-04 - val_loss: 4.5661e-04
# Epoch 159/300
#  - 0s - loss: 2.5526e-04 - val_loss: 4.3542e-04
# Epoch 160/300
#  - 0s - loss: 2.7731e-04 - val_loss: 4.0500e-04
# Epoch 161/300
#  - 0s - loss: 2.5354e-04 - val_loss: 4.5747e-04
# Epoch 162/300
#  - 0s - loss: 2.4466e-04 - val_loss: 4.1733e-04
# Epoch 163/300
#  - 0s - loss: 2.6001e-04 - val_loss: 4.0489e-04
# Epoch 164/300
#  - 0s - loss: 2.4603e-04 - val_loss: 4.5454e-04
# Epoch 165/300
#  - 0s - loss: 2.4317e-04 - val_loss: 4.0538e-04
# Epoch 166/300
#  - 0s - loss: 2.4951e-04 - val_loss: 4.0705e-04
# Epoch 167/300
#  - 0s - loss: 2.3939e-04 - val_loss: 3.8693e-04
# Epoch 168/300
#  - 0s - loss: 2.9004e-04 - val_loss: 4.2346e-04
# Epoch 169/300
#  - 0s - loss: 2.3402e-04 - val_loss: 4.1297e-04
# Epoch 170/300
#  - 0s - loss: 2.4125e-04 - val_loss: 3.9868e-04
# Epoch 171/300
#  - 0s - loss: 2.4021e-04 - val_loss: 3.9832e-04
# Epoch 172/300
#  - 0s - loss: 2.2884e-04 - val_loss: 4.0606e-04
# Epoch 173/300
#  - 0s - loss: 2.3865e-04 - val_loss: 4.0717e-04
# Epoch 174/300
#  - 0s - loss: 2.7608e-04 - val_loss: 4.8904e-04
# Epoch 175/300
#  - 0s - loss: 2.4228e-04 - val_loss: 4.0094e-04
# Epoch 176/300
#  - 0s - loss: 2.3198e-04 - val_loss: 4.7350e-04
# Epoch 177/300
#  - 0s - loss: 2.4877e-04 - val_loss: 4.7618e-04
# Epoch 178/300
#  - 0s - loss: 2.5476e-04 - val_loss: 4.1874e-04
# Epoch 179/300
#  - 0s - loss: 2.4468e-04 - val_loss: 4.7681e-04
# Epoch 180/300
#  - 0s - loss: 2.3519e-04 - val_loss: 4.5430e-04
# Epoch 181/300
#  - 0s - loss: 2.5495e-04 - val_loss: 3.9744e-04
# Epoch 182/300
#  - 0s - loss: 2.3157e-04 - val_loss: 3.9135e-04
# Epoch 183/300
#  - 0s - loss: 2.1939e-04 - val_loss: 4.0743e-04
# Epoch 184/300
#  - 0s - loss: 2.2904e-04 - val_loss: 4.3051e-04
# Epoch 185/300
#  - 0s - loss: 2.4183e-04 - val_loss: 4.3052e-04
# Epoch 186/300
#  - 0s - loss: 2.6621e-04 - val_loss: 3.8318e-04
# Epoch 187/300
#  - 0s - loss: 2.6759e-04 - val_loss: 4.1608e-04
# Epoch 188/300
#  - 0s - loss: 2.3375e-04 - val_loss: 4.6230e-04
# Epoch 189/300
#  - 0s - loss: 2.4318e-04 - val_loss: 4.2879e-04
# Epoch 190/300
#  - 0s - loss: 2.3511e-04 - val_loss: 4.9300e-04
# Epoch 191/300
#  - 0s - loss: 2.2219e-04 - val_loss: 4.1443e-04
# Epoch 192/300
#  - 0s - loss: 2.7023e-04 - val_loss: 4.3361e-04
# Epoch 193/300
#  - 0s - loss: 2.1984e-04 - val_loss: 3.8860e-04
# Epoch 194/300
#  - 0s - loss: 2.2808e-04 - val_loss: 4.0002e-04
# Epoch 195/300
#  - 0s - loss: 2.1873e-04 - val_loss: 3.7540e-04
# Epoch 196/300
#  - 0s - loss: 2.0639e-04 - val_loss: 3.8147e-04
# Epoch 197/300
#  - 0s - loss: 2.3656e-04 - val_loss: 3.9202e-04
# Epoch 198/300
#  - 0s - loss: 2.1039e-04 - val_loss: 4.0431e-04
# Epoch 199/300
#  - 0s - loss: 2.4366e-04 - val_loss: 4.2397e-04
# Epoch 200/300
#  - 0s - loss: 2.1822e-04 - val_loss: 3.8479e-04
# Epoch 201/300
#  - 0s - loss: 2.3233e-04 - val_loss: 4.2591e-04
# Epoch 202/300
#  - 0s - loss: 2.3298e-04 - val_loss: 3.8079e-04
# Epoch 203/300
#  - 0s - loss: 2.1829e-04 - val_loss: 4.1786e-04
# Epoch 204/300
#  - 0s - loss: 2.2330e-04 - val_loss: 5.0980e-04
# Epoch 205/300
#  - 0s - loss: 2.3942e-04 - val_loss: 3.7134e-04
# Epoch 206/300
#  - 0s - loss: 2.1031e-04 - val_loss: 3.8005e-04
# Epoch 207/300
#  - 0s - loss: 2.3716e-04 - val_loss: 3.6388e-04
# Epoch 208/300
#  - 0s - loss: 2.2837e-04 - val_loss: 4.9667e-04
# Epoch 209/300
#  - 0s - loss: 2.1630e-04 - val_loss: 3.7790e-04
# Epoch 210/300
#  - 0s - loss: 2.2718e-04 - val_loss: 3.9731e-04
# Epoch 211/300
#  - 0s - loss: 2.2277e-04 - val_loss: 3.7491e-04
# Epoch 212/300
#  - 0s - loss: 2.3507e-04 - val_loss: 3.9750e-04
# Epoch 213/300
#  - 0s - loss: 2.1885e-04 - val_loss: 3.8861e-04
# Epoch 214/300
#  - 0s - loss: 2.1166e-04 - val_loss: 3.7591e-04
# Epoch 215/300
#  - 0s - loss: 2.0723e-04 - val_loss: 3.6805e-04
# Epoch 216/300
#  - 0s - loss: 2.0641e-04 - val_loss: 4.4992e-04
# Epoch 217/300
#  - 0s - loss: 2.0348e-04 - val_loss: 4.0402e-04
# Epoch 218/300
#  - 0s - loss: 2.0667e-04 - val_loss: 4.4932e-04
# Epoch 219/300
#  - 0s - loss: 2.4266e-04 - val_loss: 3.7054e-04
# Epoch 220/300
#  - 0s - loss: 2.3580e-04 - val_loss: 3.9714e-04
# Epoch 221/300
#  - 0s - loss: 2.1226e-04 - val_loss: 3.7673e-04
# Epoch 222/300
#  - 0s - loss: 2.0174e-04 - val_loss: 3.9078e-04
# Epoch 223/300
#  - 0s - loss: 1.9629e-04 - val_loss: 3.9424e-04
# Epoch 224/300
#  - 0s - loss: 2.0531e-04 - val_loss: 3.7521e-04
# Epoch 225/300
#  - 0s - loss: 1.9763e-04 - val_loss: 3.9741e-04
# Epoch 226/300
#  - 0s - loss: 2.2599e-04 - val_loss: 3.7860e-04
# Epoch 227/300
#  - 0s - loss: 2.1696e-04 - val_loss: 4.0944e-04
# Epoch 228/300
#  - 0s - loss: 2.1193e-04 - val_loss: 3.8077e-04
# Epoch 229/300
#  - 0s - loss: 2.3984e-04 - val_loss: 3.9647e-04
# Epoch 230/300
#  - 0s - loss: 1.9720e-04 - val_loss: 4.4257e-04
# Epoch 231/300
#  - 0s - loss: 2.1198e-04 - val_loss: 3.8085e-04
# Epoch 232/300
#  - 0s - loss: 2.0627e-04 - val_loss: 4.6269e-04
# Epoch 233/300
#  - 0s - loss: 2.3339e-04 - val_loss: 3.8868e-04
# Epoch 234/300
#  - 0s - loss: 1.9283e-04 - val_loss: 3.7354e-04
# Epoch 235/300
#  - 0s - loss: 1.9880e-04 - val_loss: 3.7355e-04
# Epoch 236/300
#  - 0s - loss: 1.9580e-04 - val_loss: 3.7488e-04
# Epoch 237/300
#  - 0s - loss: 1.9263e-04 - val_loss: 3.8686e-04
# Epoch 238/300
#  - 0s - loss: 2.0575e-04 - val_loss: 3.8206e-04
# Epoch 239/300
#  - 0s - loss: 2.4506e-04 - val_loss: 3.7775e-04
# Epoch 240/300
#  - 0s - loss: 1.8752e-04 - val_loss: 3.8460e-04
# Epoch 241/300
#  - 0s - loss: 1.8559e-04 - val_loss: 3.5977e-04
# Epoch 242/300
#  - 0s - loss: 1.9191e-04 - val_loss: 4.3212e-04
# Epoch 243/300
#  - 0s - loss: 1.9813e-04 - val_loss: 4.0281e-04
# Epoch 244/300
#  - 0s - loss: 2.2459e-04 - val_loss: 3.9470e-04
# Epoch 245/300
#  - 0s - loss: 2.0456e-04 - val_loss: 3.9081e-04
# Epoch 246/300
#  - 0s - loss: 1.9581e-04 - val_loss: 3.9814e-04
# Epoch 247/300
#  - 0s - loss: 1.9822e-04 - val_loss: 3.8716e-04
# Epoch 248/300
#  - 0s - loss: 1.9150e-04 - val_loss: 3.7342e-04
# Epoch 249/300
#  - 0s - loss: 1.9486e-04 - val_loss: 3.9001e-04
# Epoch 250/300
#  - 0s - loss: 2.1936e-04 - val_loss: 3.8952e-04
# Epoch 251/300
#  - 0s - loss: 1.9300e-04 - val_loss: 3.8402e-04
# Epoch 252/300
#  - 0s - loss: 1.8703e-04 - val_loss: 3.8355e-04
# Epoch 253/300
#  - 0s - loss: 2.0355e-04 - val_loss: 5.2835e-04
# Epoch 254/300
#  - 0s - loss: 2.0241e-04 - val_loss: 3.6392e-04
# Epoch 255/300
#  - 0s - loss: 1.9318e-04 - val_loss: 3.8730e-04
# Epoch 256/300
#  - 0s - loss: 1.9785e-04 - val_loss: 3.8391e-04
# Epoch 257/300
#  - 0s - loss: 2.3263e-04 - val_loss: 4.2813e-04
# Epoch 258/300
#  - 0s - loss: 2.0629e-04 - val_loss: 4.4379e-04
# Epoch 259/300
#  - 0s - loss: 1.8879e-04 - val_loss: 4.2883e-04
# Epoch 260/300
#  - 0s - loss: 1.8091e-04 - val_loss: 3.7347e-04
# Epoch 261/300
#  - 0s - loss: 2.1836e-04 - val_loss: 4.1102e-04
# Epoch 262/300
#  - 0s - loss: 2.0062e-04 - val_loss: 3.7452e-04
# Epoch 263/300
#  - 0s - loss: 2.1266e-04 - val_loss: 3.7672e-04
# Epoch 264/300
#  - 0s - loss: 1.8286e-04 - val_loss: 3.7386e-04
# Epoch 265/300
#  - 0s - loss: 1.8591e-04 - val_loss: 3.7838e-04
# Epoch 266/300
#  - 0s - loss: 2.1816e-04 - val_loss: 3.5945e-04
# Epoch 267/300
#  - 0s - loss: 1.7999e-04 - val_loss: 4.2782e-04
# Epoch 268/300
#  - 0s - loss: 1.7715e-04 - val_loss: 3.7206e-04
# Epoch 269/300
#  - 0s - loss: 2.0486e-04 - val_loss: 3.5685e-04
# Epoch 270/300
#  - 0s - loss: 1.8521e-04 - val_loss: 3.6324e-04
# Epoch 271/300
#  - 0s - loss: 1.8541e-04 - val_loss: 4.5312e-04
# Epoch 272/300
#  - 0s - loss: 1.7217e-04 - val_loss: 3.6501e-04
# Epoch 273/300
#  - 0s - loss: 1.8768e-04 - val_loss: 3.8706e-04
# Epoch 274/300
#  - 0s - loss: 1.7770e-04 - val_loss: 3.6221e-04
# Epoch 275/300
#  - 0s - loss: 1.8488e-04 - val_loss: 3.5766e-04
# Epoch 276/300
#  - 0s - loss: 1.8313e-04 - val_loss: 3.7502e-04
# Epoch 277/300
#  - 0s - loss: 1.7164e-04 - val_loss: 3.8435e-04
# Epoch 278/300
#  - 0s - loss: 1.7712e-04 - val_loss: 3.6774e-04
# Epoch 279/300
#  - 0s - loss: 1.7083e-04 - val_loss: 3.8003e-04
# Epoch 280/300
#  - 0s - loss: 2.0292e-04 - val_loss: 3.9155e-04
# Epoch 281/300
#  - 0s - loss: 1.9555e-04 - val_loss: 3.8967e-04
# Epoch 282/300
#  - 0s - loss: 1.8570e-04 - val_loss: 3.6255e-04
# Epoch 283/300
#  - 0s - loss: 1.9484e-04 - val_loss: 3.8971e-04
# Epoch 284/300
#  - 0s - loss: 1.8561e-04 - val_loss: 4.1941e-04
# Epoch 285/300
#  - 0s - loss: 2.0823e-04 - val_loss: 3.7559e-04
# Epoch 286/300
#  - 0s - loss: 2.1668e-04 - val_loss: 3.5127e-04
# Epoch 287/300
#  - 0s - loss: 2.0048e-04 - val_loss: 3.6347e-04
# Epoch 288/300
#  - 0s - loss: 1.6839e-04 - val_loss: 3.6939e-04
# Epoch 289/300
#  - 0s - loss: 1.8582e-04 - val_loss: 3.7899e-04
# Epoch 290/300
#  - 0s - loss: 1.7400e-04 - val_loss: 3.5452e-04
# Epoch 291/300
#  - 0s - loss: 1.7907e-04 - val_loss: 3.5371e-04
# Epoch 292/300
#  - 0s - loss: 1.7803e-04 - val_loss: 3.6400e-04
# Epoch 293/300
#  - 0s - loss: 1.8246e-04 - val_loss: 3.4732e-04
# Epoch 294/300
#  - 0s - loss: 1.7267e-04 - val_loss: 3.6588e-04
# Epoch 295/300
#  - 0s - loss: 1.6909e-04 - val_loss: 3.5629e-04
# Epoch 296/300
#  - 0s - loss: 1.6889e-04 - val_loss: 3.9173e-04
# Epoch 297/300
#  - 0s - loss: 1.8069e-04 - val_loss: 5.1115e-04
# Epoch 298/300
#  - 0s - loss: 2.0143e-04 - val_loss: 3.9094e-04
# Epoch 299/300
#  - 0s - loss: 2.0017e-04 - val_loss: 3.6414e-04
# Epoch 300/300
#  - 0s - loss: 1.8834e-04 - val_loss: 3.6465e-04

# %%
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title("Total loss")
# Out:
# Text(0.5,1,'Total loss')

# %%
x_test.shape
y_test_pred = model.predict(x_test)

# %%
plt.scatter(y_test,y_test_pred)
plt.plot(y_test,y_test,'black')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

print('R^2: ',metrics.r2_score(y_test,y_test_pred))
# Out:
# R^2:  0.9786536707744207

# %% [markdown]
# # HVAC inputs

# %%
x_list = ['$ChillerCOP', '$ChillerPumpTypeCat','$ChillerTypeCat','Number_of_zones','Peak: Ground Floor',
       'Peak: Intermediate Floor', 'Peak: Top Floor', 'Mean: Ground Floor','Mean: Intermediate Floor', 'Mean: Top Floor']

x = data.filter(items=x_list).values
scalar_x = MinMaxScaler()
x = scalar_x.fit_transform(x)

y = data['Total: Chiller Energy'].values.reshape(len(x),1)
scalar_y = MinMaxScaler()
y = scalar_y.fit_transform(y)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = Sequential()
model.add(Dense(6, input_dim=len(x_list), activation='relu'))
model.add(Dense(1, activation='relu'))

Adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

model.compile(loss='mse', optimizer=Adam)

# %%
history = model.fit(x_train, y_train,validation_data=(x_test,y_test), epochs=100, batch_size=50, verbose=2)
# Out:
# Train on 3600 samples, validate on 900 samples
# Epoch 1/100
#  - 1s - loss: 0.0217 - val_loss: 0.0161
# Epoch 2/100
#  - 0s - loss: 0.0124 - val_loss: 0.0083
# Epoch 3/100
#  - 0s - loss: 0.0064 - val_loss: 0.0044
# Epoch 4/100
#  - 0s - loss: 0.0039 - val_loss: 0.0028
# Epoch 5/100
#  - 0s - loss: 0.0030 - val_loss: 0.0023
# Epoch 6/100
#  - 0s - loss: 0.0026 - val_loss: 0.0021
# Epoch 7/100
#  - 0s - loss: 0.0024 - val_loss: 0.0020
# Epoch 8/100
#  - 0s - loss: 0.0023 - val_loss: 0.0019
# Epoch 9/100
#  - 0s - loss: 0.0021 - val_loss: 0.0018
# Epoch 10/100
#  - 0s - loss: 0.0020 - val_loss: 0.0017
# Epoch 11/100
#  - 0s - loss: 0.0019 - val_loss: 0.0016
# Epoch 12/100
#  - 0s - loss: 0.0018 - val_loss: 0.0015
# Epoch 13/100
#  - 0s - loss: 0.0018 - val_loss: 0.0014
# Epoch 14/100
#  - 0s - loss: 0.0017 - val_loss: 0.0014
# Epoch 15/100
#  - 0s - loss: 0.0017 - val_loss: 0.0014
# Epoch 16/100
#  - 0s - loss: 0.0016 - val_loss: 0.0013
# Epoch 17/100
#  - 0s - loss: 0.0016 - val_loss: 0.0013
# Epoch 18/100
#  - 0s - loss: 0.0016 - val_loss: 0.0013
# Epoch 19/100
#  - 0s - loss: 0.0016 - val_loss: 0.0013
# Epoch 20/100
#  - 0s - loss: 0.0015 - val_loss: 0.0013
# Epoch 21/100
#  - 0s - loss: 0.0015 - val_loss: 0.0013
# Epoch 22/100
#  - 0s - loss: 0.0015 - val_loss: 0.0012
# Epoch 23/100
#  - 0s - loss: 0.0015 - val_loss: 0.0012
# Epoch 24/100
#  - 0s - loss: 0.0015 - val_loss: 0.0012
# Epoch 25/100
#  - 0s - loss: 0.0015 - val_loss: 0.0012
# Epoch 26/100
#  - 0s - loss: 0.0015 - val_loss: 0.0012
# Epoch 27/100
#  - 0s - loss: 0.0015 - val_loss: 0.0012
# Epoch 28/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 29/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 30/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 31/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 32/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 33/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 34/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 35/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 36/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 37/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 38/100
#  - 0s - loss: 0.0014 - val_loss: 0.0012
# Epoch 39/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 40/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 41/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 42/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 43/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 44/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 45/100
#  - 0s - loss: 0.0014 - val_loss: 0.0011
# Epoch 46/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 47/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 48/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 49/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 50/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 51/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 52/100
#  - 0s - loss: 0.0013 - val_loss: 0.0010
# Epoch 53/100
#  - 0s - loss: 0.0013 - val_loss: 0.0010
# Epoch 54/100
#  - 0s - loss: 0.0013 - val_loss: 0.0010
# Epoch 55/100
#  - 0s - loss: 0.0013 - val_loss: 0.0010
# Epoch 56/100
#  - 0s - loss: 0.0013 - val_loss: 0.0011
# Epoch 57/100
#  - 0s - loss: 0.0013 - val_loss: 0.0010
# Epoch 58/100
#  - 0s - loss: 0.0013 - val_loss: 0.0010
# Epoch 59/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 60/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 61/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 62/100
#  - 0s - loss: 0.0012 - val_loss: 9.9379e-04
# Epoch 63/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 64/100
#  - 0s - loss: 0.0012 - val_loss: 9.8949e-04
# Epoch 65/100
#  - 0s - loss: 0.0012 - val_loss: 9.8405e-04
# Epoch 66/100
#  - 0s - loss: 0.0012 - val_loss: 9.9292e-04
# Epoch 67/100
#  - 0s - loss: 0.0012 - val_loss: 9.8155e-04
# Epoch 68/100
#  - 0s - loss: 0.0012 - val_loss: 9.8156e-04
# Epoch 69/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 70/100
#  - 0s - loss: 0.0012 - val_loss: 9.7759e-04
# Epoch 71/100
#  - 0s - loss: 0.0012 - val_loss: 0.0011
# Epoch 72/100
#  - 0s - loss: 0.0012 - val_loss: 9.6314e-04
# Epoch 73/100
#  - 0s - loss: 0.0012 - val_loss: 9.6517e-04
# Epoch 74/100
#  - 0s - loss: 0.0012 - val_loss: 9.6096e-04
# Epoch 75/100
#  - 0s - loss: 0.0012 - val_loss: 9.6316e-04
# Epoch 76/100
#  - 0s - loss: 0.0012 - val_loss: 9.6021e-04
# Epoch 77/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 78/100
#  - 0s - loss: 0.0012 - val_loss: 0.0010
# Epoch 79/100
#  - 0s - loss: 0.0012 - val_loss: 9.6659e-04
# Epoch 80/100
#  - 0s - loss: 0.0012 - val_loss: 9.4351e-04
# Epoch 81/100
#  - 0s - loss: 0.0012 - val_loss: 9.3971e-04
# Epoch 82/100
#  - 0s - loss: 0.0012 - val_loss: 9.4467e-04
# Epoch 83/100
#  - 0s - loss: 0.0012 - val_loss: 9.3195e-04
# Epoch 84/100
#  - 0s - loss: 0.0012 - val_loss: 9.8843e-04
# Epoch 85/100
#  - 0s - loss: 0.0012 - val_loss: 9.7458e-04
# Epoch 86/100
#  - 0s - loss: 0.0012 - val_loss: 9.8713e-04
# Epoch 87/100
#  - 0s - loss: 0.0012 - val_loss: 9.2681e-04
# Epoch 88/100
#  - 0s - loss: 0.0011 - val_loss: 9.4506e-04
# Epoch 89/100
#  - 0s - loss: 0.0011 - val_loss: 9.2164e-04
# Epoch 90/100
#  - 0s - loss: 0.0011 - val_loss: 9.3515e-04
# Epoch 91/100
#  - 0s - loss: 0.0011 - val_loss: 9.2983e-04
# Epoch 92/100
#  - 0s - loss: 0.0012 - val_loss: 9.2030e-04
# Epoch 93/100
#  - 0s - loss: 0.0011 - val_loss: 9.5223e-04
# Epoch 94/100
#  - 0s - loss: 0.0011 - val_loss: 9.1162e-04
# Epoch 95/100
#  - 0s - loss: 0.0011 - val_loss: 9.3073e-04
# Epoch 96/100
#  - 0s - loss: 0.0011 - val_loss: 9.2263e-04
# Epoch 97/100
#  - 0s - loss: 0.0011 - val_loss: 9.1622e-04
# Epoch 98/100
#  - 0s - loss: 0.0011 - val_loss: 0.0011
# Epoch 99/100
#  - 0s - loss: 0.0011 - val_loss: 0.0010
# Epoch 100/100
#  - 0s - loss: 0.0011 - val_loss: 9.1261e-04

# %%
plt.plot(history.history['loss'][30:],label='Training Loss')
plt.plot(history.history['val_loss'][30:],label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('MSE')
plt.title("Total loss")
# Out:
# Text(0.5,1,'Total loss')

# %%
plt.scatter(y_test,y_test_pred)
plt.plot(y_test,y_test,'black')
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()

print('R^2: ',metrics.r2_score(y_test,y_test_pred))
# Out:
# R^2:  0.9779457779423609
